# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/preprocessed/train with city.csv')
data
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION   RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner               False  False        2       BHK  1300.236407
# 1        Dealer               False  False        2       BHK  1275.000000
# 2         Owner               False  False        2       BHK   933.159722
# 3         Owner               False   True        2       BHK   929.921143
# 4        Dealer                True  False        2       BHK   999.009247
# ...         ...                 ...    ...      ...       ...          ...
# 29245     Owner               False  False        2       BHK  1062.134891
# 29246     Owner               False  False        3       BHK  2500.000000
# 29247    Dealer               False  False        2       BHK  1022.641509
# 29248     Owner               False  False        2       BHK   927.079009
# 29249    Dealer               False   True        2       BHK   896.774194
#
# ...

# %%
plt.hist(data['TARGET(PRICE_IN_LACS)'], bins=10, edgecolor='black')
plt.title("Distribution des prix")
plt.xlabel("Prix")
plt.ylabel("Distribution")
plt.show()

# %%
plt.scatter(data['SQUARE_FT'], data['TARGET(PRICE_IN_LACS)'])
plt.title("Prix en fonction de la surface")
plt.xlabel("Surface")
plt.ylabel("Prix")
plt.show()

# %%
sns.boxplot(x='CITY', y='TARGET(PRICE_IN_LACS)', data=data)
plt.title("Prix en fonction des villes")
plt.xlabel("Ville")
plt.ylabel("Prix")
plt.show()
